# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel("Bank Transactions UPI Data.xlsx")
df
# Out:
#      Date (dd/mm/yyyy)      Time  Hours  Transaction (thousands)  \
# 0           2023-08-01  17:41:05     17                85.178140
# 1           2023-03-29  17:11:52     17                87.498126
# 2           2023-03-18  19:49:20     19               928.091061
# 3           2023-09-26  06:50:43      6               433.847430
# 4           2023-11-01  09:36:50      9               262.882716
# ...                ...       ...    ...                      ...
# 2995        2022-12-30  08:19:15      8               648.207688
# 2996        2023-11-30  12:59:40     12               595.453683
# 2997        2023-10-12  00:14:40      0               236.927873
# 2998        2022-12-31  23:00:33     23               445.453192
# 2999        2022-12-31  09:50:25      9               990.003683
#
#      Sent From Bank       City  City Size (km square)  Age  Gender  \
# 0         KreditBee      Delhi                 1483.0   22    Male
# 1        Union Bank     Mumbai                  603.4   19  Female
# 2        Union Bank  Hyderabad                  650.0   35  Female
# 3        Union Bank      Delhi                 1483.0   71  Female
# 4         Axis Bank    Chennai                  426.0   27    Male
# ...             ...        ...                    ...  ...     ...
# 2995      Axis Bank    Chennai                  426.0   77    Male
# 2996           HDFC  Bangalore                  741.0   82    Male
# 2997      KreditBee  Bangalore                  741.0   26    Male
# 2998      KreditBee  Hyderabad                  650.0   46  Female
# 2999           HDFC    Chennai                  426.0   54  Female
#
#       Bank Received   Balance (thousands)  Customer ID        Age Groups  \
# 0      Bank of India           885.330121           15             Adult
# 1      Bank of India           493.883251           13             Adult
# 2     Bank of Baroda           713.305947           11             Adult
# 3      Bank of India            51.203472            6      Senior Adult
# 4       Bandhan Bank           413.897187            1             Adult
# ...              ...                  ...          ...               ...
# 2995       KreditBee           345.116030            8      Senior Adult
# 2996   Bank of India           436.057648            8      Senior Adult
# 2997    Bandhan Bank           964.010240            6             Adult
# 2998      Union Bank           154.843255            3  Middle Age Adult
# 2999       KreditBee            73.432312           22  Middle Age Adult
#
#      Govt / Private
# 0           Private
# 1           Private
# 2              Govt
# 3           Private
# 4           Private
# ...             ...
# 2995        Private
# 2996        Private
# 2997        Private
# 2998           Govt
# 2999        Private
#
# [3000 rows x 14 columns]

# %% [markdown]
# ### Data Understand

# %%
df.shape
# Out:
# (3000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Date (dd/mm/yyyy)        3000 non-null   datetime64[ns]
#  1   Time                     3000 non-null   object
#  2   Hours                    3000 non-null   int64
#  3   Transaction (thousands)  3000 non-null   float64
#  4   Sent From Bank           3000 non-null   object
#  5   City                     3000 non-null   object
#  6   City Size (km square)    3000 non-null   float64
#  7   Age                      3000 non-null   int64
#  8   Gender                   3000 non-null   object
#  9   Bank Received            3000 non-null   object
#  10  Balance (thousands)      3000 non-null   float64
#  11  Customer ID              3000 non-null   int64
#  12  Age Groups               3000 non-null   object
#  13  Govt / Private           3000 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(3), object(7)
# memory usage: 328.3+ KB

# %%
df.describe()
# Out:
#                    Date (dd/mm/yyyy)        Hours  Transaction (thousands)  \
# count                           3000  3000.000000              3000.000000
# mean   2023-02-21 02:34:04.799999744    11.997667               533.791762
# min              2022-01-01 00:00:00     0.000000                68.032821
# 25%              2022-08-18 00:00:00     7.000000               300.962858
# 50%              2023-03-13 12:00:00    12.000000               525.320922
# 75%              2023-09-04 00:00:00    18.000000               768.333817
# max              2024-02-01 00:00:00    23.000000              1008.807429
# std                              NaN     6.729345               270.417288
#
#        City Size (km square)          Age  Balance (thousands)  Customer ID
# count            3000.000000  3000.000000          3000.000000  3000.000000
# mean              781.824267    50.344000           515.370087    11.544333
# min               426.000000    17.000000            34.135495     1.000000
# 25%               603.400000    33.000000           271.387805     6.000000
# 50%               650.000000    50.000000           519.442642    12.000000
# 75%               741.000000    68.000000           760.813343    17.000000
# max              1483.000000    84.000000           996.780463    22.000000
# std               365.436877    19.725686           280.392138     6.407370

# %%
df.dtypes
# Out:
# Date (dd/mm/yyyy)          datetime64[ns]
# Time                               object
# Hours                               int64
# Transaction (thousands)           float64
# Sent From Bank                     object
# City                               object
# City Size (km square)             float64
# Age                                 int64
# Gender                             object
# Bank Received                      object
# Balance (thousands)               float64
# Customer ID                         int64
# Age Groups                         object
# Govt / Private                     object
# dtype: object

# %%
df.columns
# Out:
# Index(['Date (dd/mm/yyyy)', 'Time', 'Hours', 'Transaction (thousands)',
#        'Sent From Bank', 'City', 'City Size (km square)', 'Age', 'Gender',
#        'Bank Received ', 'Balance (thousands)', 'Customer ID', 'Age Groups',
#        'Govt / Private'],
#       dtype='object')

# %% [markdown]
# ### Data Exploration

# %%
df.isnull().sum()
# Out:
# Date (dd/mm/yyyy)          0
# Time                       0
# Hours                      0
# Transaction (thousands)    0
# Sent From Bank             0
# City                       0
# City Size (km square)      0
# Age                        0
# Gender                     0
# Bank Received              0
# Balance (thousands)        0
# Customer ID                0
# Age Groups                 0
# Govt / Private             0
# dtype: int64

# %%
df.nunique()
# Out:
# Date (dd/mm/yyyy)           749
# Time                       2944
# Hours                        24
# Transaction (thousands)    3000
# Sent From Bank                5
# City                          5
# City Size (km square)         5
# Age                          68
# Gender                        2
# Bank Received                 8
# Balance (thousands)        3000
# Customer ID                  22
# Age Groups                    4
# Govt / Private                2
# dtype: int64

# %%
df['Date (dd/mm/yyyy)'].nunique()
# Out:
# 749

# %%
df['Date (dd/mm/yyyy)'].unique()
# Out:
# <DatetimeArray>
# ['2023-08-01 00:00:00', '2023-03-29 00:00:00', '2023-03-18 00:00:00',
#  '2023-09-26 00:00:00', '2023-11-01 00:00:00', '2023-10-22 00:00:00',
#  '2023-05-01 00:00:00', '2023-06-01 00:00:00', '2023-12-01 00:00:00',
#  '2022-01-01 00:00:00',
#  ...
#  '2022-12-23 00:00:00', '2023-01-31 00:00:00', '2022-12-25 00:00:00',
#  '2023-05-31 00:00:00', '2022-12-26 00:00:00', '2022-12-28 00:00:00',
#  '2023-12-31 00:00:00', '2022-12-29 00:00:00', '2022-12-30 00:00:00',
#  '2022-12-31 00:00:00']
# Length: 749, dtype: datetime64[ns]

# %%
df['Date (dd/mm/yyyy)'].min(),df['Date (dd/mm/yyyy)'].max()
# Out:
# (Timestamp('2022-01-01 00:00:00'), Timestamp('2024-02-01 00:00:00'))

# %%
df['Date (dd/mm/yyyy)'].value_counts().sort_index()
# Out:
# Date (dd/mm/yyyy)
# 2022-01-01    3
# 2022-01-02    3
# 2022-01-03    2
# 2022-01-04    1
# 2022-01-05    3
#              ..
# 2024-01-28    8
# 2024-01-29    1
# 2024-01-30    3
# 2024-01-31    3
# 2024-02-01    5
# Name: count, Length: 749, dtype: int64

# %%
df['Date (dd/mm/yyyy)'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Transaction (thousands)'].dtype
# Out:
# dtype('float64')

# %%
df['Transaction (thousands)'].nunique()
# Out:
# 3000

# %%
df['Transaction (thousands)'].unique()
# Out:
# array([ 85.17813954,  87.49812617, 928.09106061, ..., 236.92787282,
#        445.45319233, 990.00368277], shape=(3000,))

# %%
#to detect outliers
sns.boxplot(x='Transaction (thousands)',data=df)
# Out:
# <Axes: xlabel='Transaction (thousands)'>

# %%
df['Sent From Bank'].unique()
# Out:
# array(['KreditBee', 'Union Bank', 'Axis Bank', 'HDFC', 'ICICI'],
#       dtype=object)

# %%
df['Sent From Bank'].nunique()
# Out:
# 5

# %%
df['Sent From Bank'].dtype
# Out:
# dtype('O')

# %%
df['Sent From Bank'].value_counts()
# Out:
# Sent From Bank
# ICICI         624
# Union Bank    613
# Axis Bank     599
# HDFC          586
# KreditBee     578
# Name: count, dtype: int64

# %%
df['Sent From Bank'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Sent From Bank'].value_counts().head(10).plot(kind='barh')
# Out:
# <Axes: ylabel='Sent From Bank'>

# %%
df['City'].dtype
# Out:
# dtype('O')

# %%
df['City'].unique()
# Out:
# array(['Delhi', 'Mumbai', 'Hyderabad', 'Chennai', 'Bangalore'],
#       dtype=object)

# %%
df['City'].value_counts()
# Out:
# City
# Bangalore    616
# Hyderabad    615
# Delhi        600
# Chennai      597
# Mumbai       572
# Name: count, dtype: int64

# %%
df['City'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Age'].dtype
# Out:
# dtype('int64')

# %%
df['Age'].unique()
# Out:
# array([22, 19, 35, 71, 27, 21, 84, 23, 37, 29, 34, 46, 52, 45, 72, 77, 24,
#        75, 69, 58, 50, 61, 67, 48, 73, 26, 18, 17, 76, 54, 55, 81, 25, 51,
#        41, 57, 28, 78, 31, 42, 30, 56, 33, 63, 39, 40, 60, 82, 74, 65, 83,
#        32, 20, 70, 43, 36, 59, 53, 79, 38, 66, 62, 80, 64, 44, 68, 47, 49])

# %%
df['Age'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Age'].describe()
# Out:
# count    3000.000000
# mean       50.344000
# std        19.725686
# min        17.000000
# 25%        33.000000
# 50%        50.000000
# 75%        68.000000
# max        84.000000
# Name: Age, dtype: float64

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
df['Gender'].dtype
# Out:
# dtype('O')

# %%
df['Gender'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0         Male
# 1       Female
# 2       Female
# 3       Female
# 4         Male
#          ...
# 2995      Male
# 2996      Male
# 2997      Male
# 2998    Female
# 2999    Female
# Name: Gender, Length: 3000, dtype: object>

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      1514
# Female    1486
# Name: count, dtype: int64

# %%
df['Bank Received '].dtype
# Out:
# dtype('O')

# %%
df['Bank Received '].nunique()
# Out:
# 8

# %%
df['Bank Received '].unique()
# Out:
# array(['Bank of India', 'Bank of Baroda', 'Bandhan Bank', 'KreditBee',
#        'HDFC', 'ICICI', 'Axis Bank', 'Union Bank'], dtype=object)

# %%
df['Bank Received '].value_counts()
# Out:
# Bank Received
# HDFC              433
# Axis Bank         400
# Bandhan Bank      386
# Bank of India     383
# Union Bank        360
# Bank of Baroda    349
# ICICI             348
# KreditBee         341
# Name: count, dtype: int64

# %%
df['Bank Received '].isna().sum()
# Out:
# np.int64(0)

# %%
df['Balance (thousands)'].unique()
# Out:
# array([885.33012075, 493.88325073, 713.30594711, ..., 964.01024032,
#        154.84325476,  73.43231189], shape=(3000,))

# %%
df['Balance (thousands)'].nunique()
# Out:
# 3000

# %%
df['Balance (thousands)'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Balance (thousands)'].dtype
# Out:
# dtype('float64')

# %%
sns.boxplot(data=df,x='Balance (thousands)')
# Out:
# <Axes: xlabel='Balance (thousands)'>

# %%
df.columns.tolist()
# Out:
# ['Date (dd/mm/yyyy)',
#  'Time',
#  'Hours',
#  'Transaction (thousands)',
#  'Sent From Bank',
#  'City',
#  'City Size (km square)',
#  'Age',
#  'Gender',
#  'Bank Received ',
#  'Balance (thousands)',
#  'Customer ID',
#  'Age Groups',
#  'Govt / Private']

# %% [markdown]
# ## Data Cleaning

# %%
df.rename(columns={
    'Date (dd/mm/yyyy)':'Date',
    'Transaction (thousands)':'Transaction',
    'Balance (thousands)':'Balance',
    'Bank Received ':'Bank_Received',
    'Customer ID':'Customer_ID',
    'Age Groups':'Age_Groups',
    'City Size (km square)':'City_Size'
    
},inplace=True)

# %%
df
# Out:
#            Date      Time  Hours  Transaction Sent From Bank       City  \
# 0    2023-08-01  17:41:05     17    85.178140      KreditBee      Delhi
# 1    2023-03-29  17:11:52     17    87.498126     Union Bank     Mumbai
# 2    2023-03-18  19:49:20     19   928.091061     Union Bank  Hyderabad
# 3    2023-09-26  06:50:43      6   433.847430     Union Bank      Delhi
# 4    2023-11-01  09:36:50      9   262.882716      Axis Bank    Chennai
# ...         ...       ...    ...          ...            ...        ...
# 2995 2022-12-30  08:19:15      8   648.207688      Axis Bank    Chennai
# 2996 2023-11-30  12:59:40     12   595.453683           HDFC  Bangalore
# 2997 2023-10-12  00:14:40      0   236.927873      KreditBee  Bangalore
# 2998 2022-12-31  23:00:33     23   445.453192      KreditBee  Hyderabad
# 2999 2022-12-31  09:50:25      9   990.003683           HDFC    Chennai
#
#       City_Size  Age  Gender   Bank_Received     Balance  Customer_ID  \
# 0        1483.0   22    Male   Bank of India  885.330121           15
# 1         603.4   19  Female   Bank of India  493.883251           13
# 2         650.0   35  Female  Bank of Baroda  713.305947           11
# 3        1483.0   71  Female   Bank of India   51.203472            6
# 4         426.0   27    Male    Bandhan Bank  413.897187            1
# ...         ...  ...     ...             ...         ...          ...
# 2995      426.0   77    Male       KreditBee  345.116030            8
# 2996      741.0   82    Male   Bank of India  436.057648            8
# 2997      741.0   26    Male    Bandhan Bank  964.010240            6
# 2998      650.0   46  Female      Union Bank  154.843255            3
# 2999      426.0   54  Female       KreditBee   73.432312           22
#
#             Age_Groups Govt / Private
# 0                Adult        Private
# 1                Adult        Private
# 2                Adult           Govt
# 3         Senior Adult        Private
# 4                Adult        Private
# ...                ...            ...
# 2995      Senior Adult        Private
# 2996      Senior Adult        Private
# 2997             Adult        Private
# 2998  Middle Age Adult           Govt
# 2999  Middle Age Adult        Private
#
# [3000 rows x 14 columns]

# %%
df
# Out:
#            Date      Time  Transaction Sent From Bank       City  City_Size  \
# 0    2023-08-01  17:41:05    85.178140      KreditBee      Delhi     1483.0
# 1    2023-03-29  17:11:52    87.498126     Union Bank     Mumbai      603.4
# 2    2023-03-18  19:49:20   928.091061     Union Bank  Hyderabad      650.0
# 3    2023-09-26  06:50:43   433.847430     Union Bank      Delhi     1483.0
# 4    2023-11-01  09:36:50   262.882716      Axis Bank    Chennai      426.0
# ...         ...       ...          ...            ...        ...        ...
# 2995 2022-12-30  08:19:15   648.207688      Axis Bank    Chennai      426.0
# 2996 2023-11-30  12:59:40   595.453683           HDFC  Bangalore      741.0
# 2997 2023-10-12  00:14:40   236.927873      KreditBee  Bangalore      741.0
# 2998 2022-12-31  23:00:33   445.453192      KreditBee  Hyderabad      650.0
# 2999 2022-12-31  09:50:25   990.003683           HDFC    Chennai      426.0
#
#       Age  Gender   Bank_Received     Balance  Customer_ID        Age_Groups  \
# 0      22    Male   Bank of India  885.330121           15             Adult
# 1      19  Female   Bank of India  493.883251           13             Adult
# 2      35  Female  Bank of Baroda  713.305947           11             Adult
# 3      71  Female   Bank of India   51.203472            6      Senior Adult
# 4      27    Male    Bandhan Bank  413.897187            1             Adult
# ...   ...     ...             ...         ...          ...               ...
# 2995   77    Male       KreditBee  345.116030            8      Senior Adult
# 2996   82    Male   Bank of India  436.057648            8      Senior Adult
# 2997   26    Male    Bandhan Bank  964.010240            6             Adult
# 2998   46  Female      Union Bank  154.843255            3  Middle Age Adult
# 2999   54  Female       KreditBee   73.432312           22  Middle Age Adult
#
#      Govt / Private
# 0           Private
# 1           Private
# 2              Govt
# 3           Private
# 4           Private
# ...             ...
# 2995        Private
# 2996        Private
# 2997        Private
# 2998           Govt
# 2999        Private
#
# [3000 rows x 13 columns]

# %%
df['Date']=pd.to_datetime(df['Date'],dayfirst=True,errors='coerce')

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df.dtypes
# Out:
# Date              datetime64[ns]
# Time              datetime64[ns]
# Transaction              float64
# Sent From Bank            object
# City                      object
# City_Size                float64
# Age                        int64
# Gender                    object
# Bank_Received             object
# Balance                  float64
# Customer_ID                int64
# Age_Groups                object
# Govt / Private            object
# Year                       int32
# Month                      int32
# Day                        int32
# Weekday                   object
# Week                      UInt32
# dtype: object

# %%
# Extract required feature like day,date,week,month and year from date
df['Year']=df['Date'].dt.year
df['Month']=df['Date'].dt.month
df['Day']=df['Date'].dt.day
df['Weekday']=df['Date'].dt.day_name()
df['Week']=df['Date'].dt.isocalendar().week

# %%
df
# Out:
#            Date                Time  Transaction Sent From Bank       City  \
# 0    2023-08-01 1900-01-01 17:41:05    85.178140      KreditBee      Delhi
# 1    2023-03-29 1900-01-01 17:11:52    87.498126     Union Bank     Mumbai
# 2    2023-03-18 1900-01-01 19:49:20   928.091061     Union Bank  Hyderabad
# 3    2023-09-26 1900-01-01 06:50:43   433.847430     Union Bank      Delhi
# 4    2023-11-01 1900-01-01 09:36:50   262.882716      Axis Bank    Chennai
# ...         ...                 ...          ...            ...        ...
# 2995 2022-12-30 1900-01-01 08:19:15   648.207688      Axis Bank    Chennai
# 2996 2023-11-30 1900-01-01 12:59:40   595.453683           HDFC  Bangalore
# 2997 2023-10-12 1900-01-01 00:14:40   236.927873      KreditBee  Bangalore
# 2998 2022-12-31 1900-01-01 23:00:33   445.453192      KreditBee  Hyderabad
# 2999 2022-12-31 1900-01-01 09:50:25   990.003683           HDFC    Chennai
#
#       City_Size  Age  Gender   Bank_Received     Balance  Customer_ID  \
# 0        1483.0   22    Male   Bank of India  885.330121           15
# 1         603.4   19  Female   Bank of India  493.883251           13
# 2         650.0   35  Female  Bank of Baroda  713.305947           11
# 3        1483.0   71  Female   Bank of India   51.203472            6
# 4         426.0   27    Male    Bandhan Bank  413.897187            1
# ...         ...  ...     ...             ...         ...          ...
# 2995      426.0   77    Male       KreditBee  345.116030            8
# 2996      741.0   82    Male   Bank of India  436.057648            8
# 2997      741.0   26    Male    Bandhan Bank  964.010240            6
# 2998      650.0   46  Female      Union Bank  154.843255            3
# 2999      426.0   54  Female       KreditBee   73.432312           22
#
#             Age_Groups Govt / Private  Year  Month  Day    Weekday  Week
# 0                Adult        Private  2023      8    1    Tuesday    31
# 1                Adult        Private  2023      3   29  Wednesday    13
# 2                Adult           Govt  2023      3   18   Saturday    11
# 3         Senior Adult        Private  2023      9   26    Tuesday    39
# 4                Adult        Private  2023     11    1  Wednesday    44
# ...                ...            ...   ...    ...  ...        ...   ...
# 2995      Senior Adult        Private  2022     12   30     Friday    52
# 2996      Senior Adult        Private  2023     11   30   Thursday    48
# 2997             Adult        Private  2023     10   12   Thursday    41
# 2998  Middle Age Adult           Govt  2022     12   31   Saturday    52
# 2999  Middle Age Adult        Private  2022     12   31   Saturday    52
#
# [3000 rows x 18 columns]

# %%
df['Time']=pd.to_datetime(df['Time'],format='%H:%M:%S')

# %%
df.isna().sum()
# Out:
# Date              0
# Time              0
# Transaction       0
# Sent From Bank    0
# City              0
# City_Size         0
# Age               0
# Gender            0
# Bank_Received     0
# Balance           0
# Customer_ID       0
# Age_Groups        0
# Govt / Private    0
# Year              0
# Month             0
# Day               0
# Weekday           0
# Week              0
# dtype: int64

# %% [markdown]
# ## EDA

# %%
categorical=[
    'Sent From Bank',
    'City',
    'Gender',
    'Age_Groups',
    'Weekday',
    'Age',
    'Bank_Received'
]

# %%
continuous=[
    'Transaction',
    'Balance',
    'Age'
]

# %%
time_series=[
    'Year',       
    'Month',             
    'Day',                          
    'Week',
    'Date',    
    'Time'
]

# %%
df[continuous].describe()
# Out:
#        Transaction      Balance          Age
# count  3000.000000  3000.000000  3000.000000
# mean    533.791762   515.370087    50.344000
# std     270.417288   280.392138    19.725686
# min      68.032821    34.135495    17.000000
# 25%     300.962858   271.387805    33.000000
# 50%     525.320922   519.442642    50.000000
# 75%     768.333817   760.813343    68.000000
# max    1008.807429   996.780463    84.000000

# %%
for col in continuous:
    sns.histplot(df[col],kde=True,color='teal')
    plt.title(f'{col} Distribution')
    plt.show()

# %%
for col in categorical:
    count=df[col].value_counts()
    print(f'\n{col}:\n',count)

    sns.countplot(data=df,x=col,palette='viridis')
    plt.title(f'{col} Distribution')
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Sent From Bank:
#  Sent From Bank
# ICICI         624
# Union Bank    613
# Axis Bank     599
# HDFC          586
# KreditBee     578
# Name: count, dtype: int64
# City:
#  City
# Bangalore    616
# Hyderabad    615
# Delhi        600
# Chennai      597
# Mumbai       572
# Name: count, dtype: int64
# Gender:
#  Gender
# Male      1514
# Female    1486
# Name: count, dtype: int64
# Age_Groups:
#  Age_Groups
# Senior Adult        1109
# Adult               1007
# Middle Age Adult     844
# Teen                  40
# Name: count, dtype: int64
# Weekday:
#  Weekday
# Tuesday      448
# Friday       434
# Saturday     432
# Thursday     431
# Sunday       424
# Monday       419
# Wednesday    412
# Name: count, dtype: int64
# Age:
#  Age
# 71    62
# 77    60
# 25    57
# 28    56
# 46    55
#       ..
# 61    36
# 70    36
# 47    34
# 50    30
# 80    30
# Name: count, Length: 68, dtype: int64
# Bank_Received:
#  Bank_Received
# HDFC              433
# Axis Bank         400
# Bandhan Bank      386
# Bank of India     383
# Union Bank        360
# Bank of Baroda    349
# ICICI             348
# KreditBee         341
# Name: count, dtype: int64

# %%
print(df.groupby('Age_Groups')['Transaction'].mean())
print(df.groupby('Gender')['Transaction'].mean())
print(df.groupby('City')['Transaction'].mean())

sns.boxplot(x='Age_Groups',y='Transaction',data=df)
# Out:
# Age_Groups
# Adult               525.862410
# Middle Age Adult    545.222166
# Senior Adult        533.366047
# Teen                504.034601
# Name: Transaction, dtype: float64
# Gender
# Female    531.472044
# Male      536.068578
# Name: Transaction, dtype: float64
# City
# Bangalore    523.623716
# Chennai      538.475455
# Delhi        533.363872
# Hyderabad    535.730431
# Mumbai       538.217990
# Name: Transaction, dtype: float64
# <Axes: xlabel='Age_Groups', ylabel='Transaction'>

# %%
sns.boxplot(x='City',y='Transaction',data=df)
# Out:
# <Axes: xlabel='City', ylabel='Transaction'>

# %%
sns.boxplot(x='Gender',y='Transaction',data=df)
# Out:
# <Axes: xlabel='Gender', ylabel='Transaction'>

# %%
df.groupby('Time')['Transaction'].mean().plot(kind='bar',color='coral')
plt.ylabel('Average Transaction Value')
plt.show()

# %%
sns.heatmap(df[continuous].corr(),annot=True,cmap='coolwarm')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %%
daily=df.groupby('Date')['Transaction'].sum()
daily.plot(figsize=(10,4),title='Daily total Transactions')

monthly=df.groupby(['Ye])['Transaction'].sum()
monthly.plot(figsize=(10,4),title='Daily total Transactions')
# Out:
# <Axes: title={'center': 'Daily total Transactions'}, xlabel='Date'>

# %%
sns.scatterplot(x='Age',y='Balance',hue='Gender',data=df)
plt.title('Balance vs Age by Gender')
# Out:
# Text(0.5, 1.0, 'Balance vs Age by Gender')
